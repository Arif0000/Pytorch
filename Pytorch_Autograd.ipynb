# %% [markdown]
# <a href="https://colab.research.google.com/github/Arif0000/Pytorch/blob/main/Pytorch_Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x ** 2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
import math

def dz_dx(x):
  return 2 * x * math.cos(x ** 2)

# %%
dz_dx(4)
# Out:
# -7.661275842587077

# %%
x = torch.tensor(4.0, requires_grad=True)
y = x ** 2
z=torch.sin(y)
print(x)
print(y)
print(z)
# Out:
# tensor(4., requires_grad=True)
# tensor(16., grad_fn=<PowBackward0>)
# tensor(-0.2879, grad_fn=<SinBackward0>)

# %%
print(z.backward())
print(x.grad)
print(y.grad)
# Out:
# None
# tensor(-7.6613)
# None
# /tmp/ipython-input-280/2625773926.py:3: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:492.)
#   print(y.grad)

# %%
import torch
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_cross_entropy_loss(prediction, target):
  epsilon = 1e-8
  prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
  return - (target * torch.log(prediction) + (1 - target) * torch.log(1-prediction))

# %%
z = w * x + b
y_pred = torch.sigmoid(z)
loss = binary_cross_entropy_loss(y_pred, y)
print(loss)
# Out:
# tensor(6.7012)

# %%
# Derivatives
dloss_dy_pred = (y_pred - y)/(y_pred * (1-y_pred))
dy_pred_dz = y_pred * (1 - y_pred)
dz_dw = x
dz_db =1

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

print(f"Manual G of lo wrt {dL_dw} dw")
print(f"Manual G of lo wrt {dL_db} db")
# Out:
# Manual G of lo wrt 6.691762447357178 dw
# Manual G of lo wrt 0.998770534992218 db

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)
print(w)
print(b)
# Out:
# tensor(1., requires_grad=True)
# tensor(0., requires_grad=True)

# %%
z = w * x + b
print(z)
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
from prompt_toolkit.shortcuts.dialogs import yes_no_dialog
y_pred = torch.sigmoid(z)
print(y_pred)
loss = binary_cross_entropy_loss(y_pred,y)
print(loss)
print(loss.backward())
print(w.grad)
print(b.grad)
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)
# tensor(6.7012, grad_fn=<NegBackward0>)
# None
# tensor(6.6918)
# tensor(0.9988)

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
print(x)
y = (x **2).mean()
print(y)
print(y.backward())
print(x.grad)
# Out:
# tensor([1., 2., 3.], requires_grad=True)
# tensor(4.6667, grad_fn=<MeanBackward0>)
# None
# tensor([0.6667, 1.3333, 2.0000])

# %%
x = torch.tensor(2.0, requires_grad=True)
print(x)
y = x **2
print(y)
print(y.backward())
print(x.grad)
print(x.grad.zero_())
# Out:
# tensor(2., requires_grad=True)
# tensor(4., grad_fn=<PowBackward0>)
# None
# tensor(4.)
# tensor(0.)

# %%
#disable gradient tracking
x = torch.tensor(2.0, requires_grad=True)
print(x)
y = x ** 2
print(y)
print(y.backward())
print(x.grad)
print(x.requires_grad_(False))
print(x)
y = x ** 2
print(y)
print(y.backward())
# Out:
# tensor(2., requires_grad=True)
# tensor(4., grad_fn=<PowBackward0>)
# None
# tensor(4.)
# tensor(2.)
# tensor(2.)
# tensor(4.)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-280/2624898165.py in <cell line: 0>()
#      10 y = x ** 2
#      11 print(y)
# ---> 12 print(y.backward())
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     362     # some Python versions print out the first line of a multi-line function
# ...
