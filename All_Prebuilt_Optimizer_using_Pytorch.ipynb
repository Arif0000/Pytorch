# %% [markdown]
# <a href="https://colab.research.google.com/github/Arif0000/Pytorch/blob/main/All_Prebuilt_Optimizer_using_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.optim as optim

# %%
optimizer_batch_gd = optim.SGD(params, lr=0.1)

# %%
optimizer_sgd = optim.SGD(params, lr=0.1)

# %%
optimizer_mini_batch_gd = optim.SGD(params, lr=0.1)

# %%
optimizer_sgd_momentum = optim.SGD(params, lr=0.1, momentum=0.9)

# %%
optimizer_nesterov = optim.SGD(params. lr=0.1, momentum=0.9, nesterov=True)

# %%
optimizer_adagrad = optim.Adagrad(params, lr=0.1, eps=1e-8)

# %%
optimizer_rmsprop = optim_RMSprop(params, lr=0.1, alpha=0.99, eps=1e-8)

# %%
optimizer_adam = optim.Adam(params. lr=0.1, betas=(0.9, 0.99), eps=1e-8)
